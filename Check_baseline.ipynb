# %% [markdown]
# <a href="https://colab.research.google.com/github/YamatoGH/competent-tiny-LLM-project/blob/main/Check_baseline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ベースラインを確認します

# %%
# !pip install transformers datasets evaluate accelerate
# !pip install openai-human-eval
# !git clone https://github.com/EleutherAI/lm-evaluation-harness.git && cd lm-evaluation-harness && pip install -e .
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement openai-human-eval (from versions: none)
# ERROR: No matching distribution found for openai-human-eval
# fatal: destination path 'lm-evaluation-harness' already exists and is not an empty directory.

# %%
# MMLU

# !cd lm-evaluation-harness && python -m lm_eval --model hf --model_args pretrained="elyza/Llama-3-ELYZA-JP-8B" --tasks mmlu --device cuda
# !cd lm-evaluation-harness && python -m lm_eval --model hf --model_args pretrained="TinyLlama/TinyLlama-1.1B-Chat-v1.0" --tasks mmlu --device cuda
# Out:
# 2025-01-27 10:25:57.807562: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-27 10:25:57.825357: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-27 10:25:57.846558: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-27 10:25:57.853011: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# HellaSwag, TruthfulQA, BBH, GSM8K, Winogrande(現在ARCは評価してません)

# !cd lm-evaluation-harness && python -m lm_eval --model hf --model_args pretrained="elyza/Llama-3-ELYZA-JP-8B" --tasks hellaswag,truthfulqa,bbh,gsm8k,winogrande --device cuda
# !cd lm-evaluation-harness && python -m lm_eval --model hf --model_args pretrained="TinyLlama/TinyLlama-1.1B-Chat-v1.0" --tasks hellaswag,truthfulqa,bbh,gsm8k,winogrande --device cuda
# Out:
# 2025-01-27 10:46:36.848461: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-27 10:46:36.866339: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-27 10:46:36.887711: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-27 10:46:36.894245: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# MT-Bench

# !cd FastChat && python fastchat/llm_judge.py --model "elyza/Llama-3-ELYZA-JP-8B"
# !cd FastChat && python fastchat/llm_judge.py --model "TinyLlama/TinyLlama-1.1B-Chat-v1.0"

# %%
# Human-Eval

# !evaluate_functional_correctness --model_path "elyza/Llama-3-ELYZA-JP-8B"
# !evaluate_functional_correctness --model_path "TinyLlama/TinyLlama-1.1B-Chat-v1.0"
